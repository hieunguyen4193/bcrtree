# %%
import pandas as pd
import pathlib
import os

outdir = "/home/hieunguyen/CRC1382/outdir/molmed_server"
PROJECT = "mixcr_pipeline_output"

maindir = os.path.join(outdir, PROJECT)
path_to_main_output = os.path.join(maindir, "data_analysis")
path_to_05_output = os.path.join(path_to_main_output, "05_output")

thres = 0.15
maindf = pd.DataFrame()
all_count_files = [item for item in pathlib.Path(os.path.join(path_to_05_output)).glob("*/*/*/*count*")]
for file in all_count_files:
    basedir = "/".join(str(file).split("/")[:-1])
    tmpdf = pd.read_csv(file, index_col = [0])
    mouseid = str(file).split("/")[-3]
    analysis_type = str(file).split("/")[-2].replace("_MIDs", "")
    tmpdf["mouseID"] = mouseid
    tmpdf["analysis_type"] = analysis_type
    tmpdf["filename"] = tmpdf["VJ.combi"].apply(lambda x: x.replace("*", "-"))
    tmpdf["path"] = tmpdf["filename"].apply(lambda x: "{}/{}_{}_{}.aln.fasta".format(basedir, mouseid, analysis_type, x))
    
    tmpdf["filename"] = tmpdf[["mouseID", "analysis_type", "filename"]].apply(lambda x: "_".join(x), axis = 1)
    maindf = pd.concat([maindf, tmpdf], axis = 0)

maindf = maindf.sort_values(by = ["count.seq"], ascending=True)
maindf.to_csv("all_fasta_SampleSheet.csv", index = False)

count = 0
for mouseid in maindf["mouseID"].unique():
    for analysis_type in maindf["analysis_type"].unique():
        tmpdf = maindf[(maindf["mouseID"] == mouseid) & (maindf["analysis_type"] == analysis_type)]
        tmpdf.to_csv("./SampleSheets/{}_{}_SampleSheet.csv".format(mouseid, analysis_type), index = False)
        count += tmpdf.shape[0]

# %%
maindf
# Out:
#                       VJ.combi  count.seq mouseID analysis_type  \
# 322      IGHV2-9_IGHJ4*01_36_1          2     m13       all_YFP
# 150     IGHV1-62_IGHJ3*01_39_2          2     m31    biopsy_YFP
# 323      IGHV2-9_IGHJ4*01_36_2          2     m13       all_YFP
# 178      IGHV2-9_IGHJ2*01_39_2          2     m39       all_YFP
# 177      IGHV2-9_IGHJ2*01_39_1          2     m39       all_YFP
# ..                         ...        ...     ...           ...
# 29   IGHV1-47*01_IGHJ4*01_42_1        437     m30       neg_YFP
# 1    IGHV1-59*01_IGHJ3*01_42_1        465     m13       pos_YFP
# 1    IGHV1-59*01_IGHJ3*01_42_1        465     m13       all_YFP
# 140  IGHV10-1*01_IGHJ2*01_45_1        479     m14       all_YFP
# 113  IGHV1-47*01_IGHJ4*01_42_1        514     m30       all_YFP
#
#                                   filename  \
# 322      m13_all_YFP_IGHV2-9_IGHJ4-01_36_1
# 150  m31_biopsy_YFP_IGHV1-62_IGHJ3-01_39_2
# 323      m13_all_YFP_IGHV2-9_IGHJ4-01_36_2
# 178      m39_all_YFP_IGHV2-9_IGHJ2-01_39_2
# 177      m39_all_YFP_IGHV2-9_IGHJ2-01_39_1
# ..                                     ...
# 29   m30_neg_YFP_IGHV1-47-01_IGHJ4-01_42_1
# 1    m13_pos_YFP_IGHV1-59-01_IGHJ3-01_42_1
# 1    m13_all_YFP_IGHV1-59-01_IGHJ3-01_42_1
# 140  m14_all_YFP_IGHV10-1-01_IGHJ2-01_45_1
# 113  m30_all_YFP_IGHV1-47-01_IGHJ4-01_42_1
#
#                                                   path
# 322  /home/hieunguyen/CRC1382/outdir/molmed_server/...
# 150  /home/hieunguyen/CRC1382/outdir/molmed_server/...
# 323  /home/hieunguyen/CRC1382/outdir/molmed_server/...
# 178  /home/hieunguyen/CRC1382/outdir/molmed_server/...
# 177  /home/hieunguyen/CRC1382/outdir/molmed_server/...
# ..                                                 ...
# 29   /home/hieunguyen/CRC1382/outdir/molmed_server/...
# 1    /home/hieunguyen/CRC1382/outdir/molmed_server/...
# 1    /home/hieunguyen/CRC1382/outdir/molmed_server/...
# 140  /home/hieunguyen/CRC1382/outdir/molmed_server/...
# 113  /home/hieunguyen/CRC1382/outdir/molmed_server/...
#
# [14325 rows x 6 columns]
